# %%
import os
import numpy as np
import glob
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img

# %% [markdown]
# # Building the DataGenerator

# %%
# Image data generator with the transformations
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=[0.4, 1.5],
    channel_shift_range=0.5,
    shear_range=0.2,
    zoom_range=[1, 1.3],
    horizontal_flip=True
)

# %% [markdown]
# # Executing the DataGenerator

# %%
# Directory where the images are located
DIR = "/content/sample_data/Final_Project_pics"

# Number of augmentation per pic
NUM_OF_AUG = 20

# %%
processed_filenames = set()  # Set to store processed filenames
counter = 0
for filename in os.listdir(DIR):
    if filename.endswith(".jpg") or filename.endswith(".png") and "_augmented" not in filename:
        counter +=1
        # Load the image file
        img = load_img(os.path.join(DIR, filename))
        # Convert the image to a numpy array and reshape
        img_array = img_to_array(img).reshape((1,) + img_to_array(img).shape)

        # The original name of the image file without the extension
        image_name = os.path.splitext(filename)[0]

        # Check if the image has already been processed
        if image_name in processed_filenames:
            print(f"Skipping augmentation for {filename}. Already processed.")
            continue

        # We want NUM_OF_AUG augmentations per image
        for i, batch in enumerate(datagen.flow(img_array, batch_size=1,
                                                save_to_dir=DIR,
                                                save_prefix=image_name+"_augmented",
                                                save_format='jpg')):
            if i == NUM_OF_AUG - 1:
                # Stop after NUM_OF_AUG images
                break
    processed_filenames.add(image_name)
    print(f"Image number {counter} augmented. Mooving on to the next image...")
# Out:
# Image number 1 augmented. Mooving on to the next image...
# Image number 2 augmented. Mooving on to the next image...
# Image number 3 augmented. Mooving on to the next image...
# Image number 4 augmented. Mooving on to the next image...
# Image number 5 augmented. Mooving on to the next image...
# Image number 6 augmented. Mooving on to the next image...
# Image number 7 augmented. Mooving on to the next image...
# Image number 8 augmented. Mooving on to the next image...
# Image number 9 augmented. Mooving on to the next image...
# Image number 10 augmented. Mooving on to the next image...
# Image number 11 augmented. Mooving on to the next image...
# Image number 12 augmented. Mooving on to the next image...
# Image number 13 augmented. Mooving on to the next image...
# Image number 14 augmented. Mooving on to the next image...
# Image number 15 augmented. Mooving on to the next image...
# Image number 16 augmented. Mooving on to the next image...
# Image number 17 augmented. Mooving on to the next image...
# Image number 18 augmented. Mooving on to the next image...
# Image number 19 augmented. Mooving on to the next image...
# Image number 20 augmented. Mooving on to the next image...
# Image number 21 augmented. Mooving on to the next image...
# Image number 22 augmented. Mooving on to the next image...
# Image number 23 augmented. Mooving on to the next image...
# Image number 24 augmented. Mooving on to the next image...
# Image number 25 augmented. Mooving on to the next image...
# Image number 26 augmented. Mooving on to the next image...
# Image number 27 augmented. Mooving on to the next image...
# Image number 28 augmented. Mooving on to the next image...
# Image number 29 augmented. Mooving on to the next image...
# Image number 30 augmented. Mooving on to the next image...
# Image number 31 augmented. Mooving on to the next image...
# Image number 32 augmented. Mooving on to the next image...
# Image number 33 augmented. Mooving on to the next image...
# Image number 34 augmented. Mooving on to the next image...
# Image number 35 augmented. Mooving on to the next image...
# Image number 36 augmented. Mooving on to the next image...
# Image number 37 augmented. Mooving on to the next image...
# Image number 38 augmented. Mooving on to the next image...
# Image number 39 augmented. Mooving on to the next image...
# Image number 40 augmented. Mooving on to the next image...
# Image number 41 augmented. Mooving on to the next image...
# Image number 42 augmented. Mooving on to the next image...
# Image number 43 augmented. Mooving on to the next image...
# Image number 44 augmented. Mooving on to the next image...
# Image number 45 augmented. Mooving on to the next image...
# Image number 46 augmented. Mooving on to the next image...
# Image number 47 augmented. Mooving on to the next image...
# Image number 48 augmented. Mooving on to the next image...
# Image number 49 augmented. Mooving on to the next image...
# Image number 50 augmented. Mooving on to the next image...
# Image number 51 augmented. Mooving on to the next image...
# Image number 52 augmented. Mooving on to the next image...
# Image number 53 augmented. Mooving on to the next image...
# Image number 54 augmented. Mooving on to the next image...
# Image number 55 augmented. Mooving on to the next image...
# Image number 56 augmented. Mooving on to the next image...
# Image number 57 augmented. Mooving on to the next image...
# Image number 58 augmented. Mooving on to the next image...
# Image number 59 augmented. Mooving on to the next image...
# Image number 60 augmented. Mooving on to the next image...
# Image number 61 augmented. Mooving on to the next image...
# Image number 62 augmented. Mooving on to the next image...
# Image number 63 augmented. Mooving on to the next image...
# Image number 64 augmented. Mooving on to the next image...
# Image number 65 augmented. Mooving on to the next image...
# Image number 66 augmented. Mooving on to the next image...
# Image number 67 augmented. Mooving on to the next image...
# Image number 68 augmented. Mooving on to the next image...
# Image number 69 augmented. Mooving on to the next image...
# Image number 70 augmented. Mooving on to the next image...
# Image number 71 augmented. Mooving on to the next image...
# Image number 72 augmented. Mooving on to the next image...
# Image number 73 augmented. Mooving on to the next image...
# Image number 74 augmented. Mooving on to the next image...
# Image number 75 augmented. Mooving on to the next image...
# Image number 76 augmented. Mooving on to the next image...
# Image number 77 augmented. Mooving on to the next image...
# Image number 78 augmented. Mooving on to the next image...
# Image number 79 augmented. Mooving on to the next image...
# Image number 80 augmented. Mooving on to the next image...
# Image number 81 augmented. Mooving on to the next image...
# Image number 82 augmented. Mooving on to the next image...
# Image number 83 augmented. Mooving on to the next image...
# Image number 84 augmented. Mooving on to the next image...
# Image number 85 augmented. Mooving on to the next image...
# Image number 86 augmented. Mooving on to the next image...
# Image number 87 augmented. Mooving on to the next image...
# Image number 88 augmented. Mooving on to the next image...
# Image number 89 augmented. Mooving on to the next image...
# Image number 90 augmented. Mooving on to the next image...
# Image number 91 augmented. Mooving on to the next image...
# Image number 92 augmented. Mooving on to the next image...
# Image number 93 augmented. Mooving on to the next image...
# Image number 94 augmented. Mooving on to the next image...
# Image number 95 augmented. Mooving on to the next image...
# Image number 96 augmented. Mooving on to the next image...
# Image number 97 augmented. Mooving on to the next image...
# Image number 98 augmented. Mooving on to the next image...
# Image number 99 augmented. Mooving on to the next image...
# Image number 100 augmented. Mooving on to the next image...
# Image number 101 augmented. Mooving on to the next image...
# Image number 102 augmented. Mooving on to the next image...
# Image number 103 augmented. Mooving on to the next image...
# Image number 104 augmented. Mooving on to the next image...
# Image number 105 augmented. Mooving on to the next image...
# Image number 106 augmented. Mooving on to the next image...
# Image number 107 augmented. Mooving on to the next image...
# Image number 108 augmented. Mooving on to the next image...
# Image number 109 augmented. Mooving on to the next image...
# Image number 110 augmented. Mooving on to the next image...
# Image number 111 augmented. Mooving on to the next image...
# Image number 112 augmented. Mooving on to the next image...
# Image number 113 augmented. Mooving on to the next image...
# Image number 114 augmented. Mooving on to the next image...
# Image number 115 augmented. Mooving on to the next image...
# Image number 116 augmented. Mooving on to the next image...
# Image number 117 augmented. Mooving on to the next image...
# Image number 118 augmented. Mooving on to the next image...
# Image number 119 augmented. Mooving on to the next image...
# Image number 120 augmented. Mooving on to the next image...
# Image number 121 augmented. Mooving on to the next image...
# Image number 122 augmented. Mooving on to the next image...
# Image number 123 augmented. Mooving on to the next image...
# Image number 124 augmented. Mooving on to the next image...
# Image number 125 augmented. Mooving on to the next image...
# Image number 126 augmented. Mooving on to the next image...
# Image number 127 augmented. Mooving on to the next image...
# Image number 128 augmented. Mooving on to the next image...
# Image number 129 augmented. Mooving on to the next image...
# Image number 130 augmented. Mooving on to the next image...
# Image number 131 augmented. Mooving on to the next image...
# Image number 132 augmented. Mooving on to the next image...
# Image number 133 augmented. Mooving on to the next image...
# Image number 134 augmented. Mooving on to the next image...
# Image number 135 augmented. Mooving on to the next image...
# Image number 136 augmented. Mooving on to the next image...
# Image number 137 augmented. Mooving on to the next image...
# Image number 138 augmented. Mooving on to the next image...
# Image number 139 augmented. Mooving on to the next image...
# Image number 140 augmented. Mooving on to the next image...
# Image number 141 augmented. Mooving on to the next image...
# Image number 142 augmented. Mooving on to the next image...
# Image number 143 augmented. Mooving on to the next image...
# Image number 144 augmented. Mooving on to the next image...
# Image number 145 augmented. Mooving on to the next image...
# Image number 146 augmented. Mooving on to the next image...
# Image number 147 augmented. Mooving on to the next image...
# Image number 148 augmented. Mooving on to the next image...
# Image number 149 augmented. Mooving on to the next image...
# Image number 150 augmented. Mooving on to the next image...
# Image number 151 augmented. Mooving on to the next image...
# Image number 152 augmented. Mooving on to the next image...
# Image number 153 augmented. Mooving on to the next image...
# Image number 154 augmented. Mooving on to the next image...
# Image number 155 augmented. Mooving on to the next image...
# Image number 156 augmented. Mooving on to the next image...
# Image number 157 augmented. Mooving on to the next image...
# Image number 158 augmented. Mooving on to the next image...
# Image number 159 augmented. Mooving on to the next image...
# Image number 160 augmented. Mooving on to the next image...
# Image number 161 augmented. Mooving on to the next image...
# Image number 162 augmented. Mooving on to the next image...
# Image number 163 augmented. Mooving on to the next image...
# Image number 164 augmented. Mooving on to the next image...
# Image number 165 augmented. Mooving on to the next image...
# Image number 166 augmented. Mooving on to the next image...
# Image number 167 augmented. Mooving on to the next image...
# Image number 168 augmented. Mooving on to the next image...
# Image number 169 augmented. Mooving on to the next image...
# Image number 170 augmented. Mooving on to the next image...
# Image number 171 augmented. Mooving on to the next image...
# Image number 172 augmented. Mooving on to the next image...
# Image number 173 augmented. Mooving on to the next image...
# Image number 174 augmented. Mooving on to the next image...
# Image number 175 augmented. Mooving on to the next image...
# Image number 176 augmented. Mooving on to the next image...
# Image number 177 augmented. Mooving on to the next image...
# Image number 178 augmented. Mooving on to the next image...
# Image number 179 augmented. Mooving on to the next image...
# Image number 180 augmented. Mooving on to the next image...
# Image number 181 augmented. Mooving on to the next image...
# Image number 182 augmented. Mooving on to the next image...
# Image number 183 augmented. Mooving on to the next image...
# Image number 184 augmented. Mooving on to the next image...
# Image number 185 augmented. Mooving on to the next image...
# Image number 186 augmented. Mooving on to the next image...
# Image number 187 augmented. Mooving on to the next image...
# Image number 188 augmented. Mooving on to the next image...
# Image number 189 augmented. Mooving on to the next image...
# Image number 190 augmented. Mooving on to the next image...
# Image number 191 augmented. Mooving on to the next image...
# Image number 192 augmented. Mooving on to the next image...
# Image number 193 augmented. Mooving on to the next image...
# Image number 194 augmented. Mooving on to the next image...
# Image number 195 augmented. Mooving on to the next image...
# Image number 196 augmented. Mooving on to the next image...
# Image number 197 augmented. Mooving on to the next image...
# Image number 198 augmented. Mooving on to the next image...
# Image number 199 augmented. Mooving on to the next image...
# Image number 200 augmented. Mooving on to the next image...
# Image number 201 augmented. Mooving on to the next image...
# Image number 202 augmented. Mooving on to the next image...
# Image number 203 augmented. Mooving on to the next image...
# Image number 204 augmented. Mooving on to the next image...
# Image number 205 augmented. Mooving on to the next image...
# Image number 206 augmented. Mooving on to the next image...
# Image number 207 augmented. Mooving on to the next image...
# Image number 208 augmented. Mooving on to the next image...
# Image number 209 augmented. Mooving on to the next image...
# Image number 210 augmented. Mooving on to the next image...
# Image number 211 augmented. Mooving on to the next image...
# Image number 212 augmented. Mooving on to the next image...
# Image number 213 augmented. Mooving on to the next image...
# Image number 214 augmented. Mooving on to the next image...
# Image number 215 augmented. Mooving on to the next image...
# Image number 216 augmented. Mooving on to the next image...
# Image number 217 augmented. Mooving on to the next image...
# Image number 218 augmented. Mooving on to the next image...
# Image number 219 augmented. Mooving on to the next image...
# Image number 220 augmented. Mooving on to the next image...
# Image number 221 augmented. Mooving on to the next image...
# Image number 222 augmented. Mooving on to the next image...
# Image number 223 augmented. Mooving on to the next image...
# Image number 224 augmented. Mooving on to the next image...
# Image number 225 augmented. Mooving on to the next image...
# Image number 226 augmented. Mooving on to the next image...
# Image number 227 augmented. Mooving on to the next image...
# Image number 228 augmented. Mooving on to the next image...
# Image number 229 augmented. Mooving on to the next image...
# Image number 230 augmented. Mooving on to the next image...
# Image number 231 augmented. Mooving on to the next image...
# Image number 232 augmented. Mooving on to the next image...
# Image number 233 augmented. Mooving on to the next image...
# Image number 234 augmented. Mooving on to the next image...
# Image number 235 augmented. Mooving on to the next image...
# Image number 236 augmented. Mooving on to the next image...
# Image number 237 augmented. Mooving on to the next image...
# Image number 238 augmented. Mooving on to the next image...
# Image number 239 augmented. Mooving on to the next image...
# Image number 240 augmented. Mooving on to the next image...
# Image number 241 augmented. Mooving on to the next image...
# Image number 242 augmented. Mooving on to the next image...
# Image number 243 augmented. Mooving on to the next image...
# Image number 244 augmented. Mooving on to the next image...
# Image number 245 augmented. Mooving on to the next image...
# Image number 246 augmented. Mooving on to the next image...
# Image number 247 augmented. Mooving on to the next image...
# Image number 248 augmented. Mooving on to the next image...
# Image number 249 augmented. Mooving on to the next image...
# Image number 250 augmented. Mooving on to the next image...
# Image number 251 augmented. Mooving on to the next image...
# Image number 252 augmented. Mooving on to the next image...
# Image number 253 augmented. Mooving on to the next image...
# Image number 254 augmented. Mooving on to the next image...
# Image number 255 augmented. Mooving on to the next image...
# Image number 256 augmented. Mooving on to the next image...
# Image number 257 augmented. Mooving on to the next image...
# Image number 258 augmented. Mooving on to the next image...
# Image number 259 augmented. Mooving on to the next image...
# Image number 260 augmented. Mooving on to the next image...
# Image number 261 augmented. Mooving on to the next image...
# Image number 262 augmented. Mooving on to the next image...
# Image number 263 augmented. Mooving on to the next image...
# Image number 264 augmented. Mooving on to the next image...
# Image number 265 augmented. Mooving on to the next image...
# Image number 266 augmented. Mooving on to the next image...
# Image number 267 augmented. Mooving on to the next image...
# Image number 268 augmented. Mooving on to the next image...
# Image number 269 augmented. Mooving on to the next image...
# Image number 270 augmented. Mooving on to the next image...
# Image number 271 augmented. Mooving on to the next image...
# Image number 272 augmented. Mooving on to the next image...
# Image number 273 augmented. Mooving on to the next image...
# Image number 274 augmented. Mooving on to the next image...
# Image number 275 augmented. Mooving on to the next image...
# Image number 276 augmented. Mooving on to the next image...
# Image number 277 augmented. Mooving on to the next image...
# Image number 278 augmented. Mooving on to the next image...
# Image number 279 augmented. Mooving on to the next image...
# Image number 280 augmented. Mooving on to the next image...
# Image number 281 augmented. Mooving on to the next image...
# Image number 282 augmented. Mooving on to the next image...
# Image number 283 augmented. Mooving on to the next image...
# Image number 284 augmented. Mooving on to the next image...
# Image number 285 augmented. Mooving on to the next image...
# Image number 286 augmented. Mooving on to the next image...
# Image number 287 augmented. Mooving on to the next image...
# Image number 288 augmented. Mooving on to the next image...
# Image number 289 augmented. Mooving on to the next image...
# Image number 290 augmented. Mooving on to the next image...
# Image number 291 augmented. Mooving on to the next image...
# Image number 292 augmented. Mooving on to the next image...
# Image number 293 augmented. Mooving on to the next image...
# Image number 294 augmented. Mooving on to the next image...
# Image number 295 augmented. Mooving on to the next image...
# Image number 296 augmented. Mooving on to the next image...
# Image number 297 augmented. Mooving on to the next image...
# Image number 298 augmented. Mooving on to the next image...
# Image number 299 augmented. Mooving on to the next image...
# Image number 300 augmented. Mooving on to the next image...
# Image number 301 augmented. Mooving on to the next image...
# Image number 302 augmented. Mooving on to the next image...
# Image number 303 augmented. Mooving on to the next image...
# Image number 304 augmented. Mooving on to the next image...
# Image number 305 augmented. Mooving on to the next image...
# Image number 306 augmented. Mooving on to the next image...
# Image number 307 augmented. Mooving on to the next image...
# Image number 308 augmented. Mooving on to the next image...
# Image number 309 augmented. Mooving on to the next image...
# Image number 310 augmented. Mooving on to the next image...
# Image number 311 augmented. Mooving on to the next image...
# Image number 312 augmented. Mooving on to the next image...
# Image number 313 augmented. Mooving on to the next image...
# Image number 314 augmented. Mooving on to the next image...
# Image number 315 augmented. Mooving on to the next image...
# Image number 316 augmented. Mooving on to the next image...
# Image number 317 augmented. Mooving on to the next image...
# Image number 318 augmented. Mooving on to the next image...
# Image number 319 augmented. Mooving on to the next image...
# Image number 320 augmented. Mooving on to the next image...
# Image number 321 augmented. Mooving on to the next image...
# Image number 322 augmented. Mooving on to the next image...
# Image number 323 augmented. Mooving on to the next image...
# Image number 324 augmented. Mooving on to the next image...
# Image number 325 augmented. Mooving on to the next image...
# Image number 326 augmented. Mooving on to the next image...
# Image number 327 augmented. Mooving on to the next image...
# Image number 328 augmented. Mooving on to the next image...
# Image number 329 augmented. Mooving on to the next image...
# Image number 330 augmented. Mooving on to the next image...
# Image number 331 augmented. Mooving on to the next image...
# Image number 332 augmented. Mooving on to the next image...
# Image number 333 augmented. Mooving on to the next image...
# Image number 334 augmented. Mooving on to the next image...
# Image number 335 augmented. Mooving on to the next image...
# Image number 336 augmented. Mooving on to the next image...
# Image number 337 augmented. Mooving on to the next image...
# Image number 338 augmented. Mooving on to the next image...
# Image number 339 augmented. Mooving on to the next image...
# Image number 340 augmented. Mooving on to the next image...
# Image number 341 augmented. Mooving on to the next image...
# Image number 342 augmented. Mooving on to the next image...
# Image number 343 augmented. Mooving on to the next image...
# Image number 344 augmented. Mooving on to the next image...
# Image number 345 augmented. Mooving on to the next image...
# Image number 346 augmented. Mooving on to the next image...
# Image number 347 augmented. Mooving on to the next image...
# Image number 348 augmented. Mooving on to the next image...
# Image number 349 augmented. Mooving on to the next image...
# Image number 350 augmented. Mooving on to the next image...
# Image number 351 augmented. Mooving on to the next image...
# Image number 352 augmented. Mooving on to the next image...
# Image number 353 augmented. Mooving on to the next image...
# Image number 354 augmented. Mooving on to the next image...
# Image number 355 augmented. Mooving on to the next image...
# Image number 356 augmented. Mooving on to the next image...
# Image number 357 augmented. Mooving on to the next image...
# Image number 358 augmented. Mooving on to the next image...
# Image number 359 augmented. Mooving on to the next image...
# Image number 360 augmented. Mooving on to the next image...
# Image number 361 augmented. Mooving on to the next image...
# Image number 362 augmented. Mooving on to the next image...
# Image number 363 augmented. Mooving on to the next image...
# Image number 364 augmented. Mooving on to the next image...
# Image number 365 augmented. Mooving on to the next image...
# Image number 366 augmented. Mooving on to the next image...
# Image number 367 augmented. Mooving on to the next image...
# Image number 368 augmented. Mooving on to the next image...
# Image number 369 augmented. Mooving on to the next image...
# Image number 370 augmented. Mooving on to the next image...
# Image number 371 augmented. Mooving on to the next image...
# Image number 372 augmented. Mooving on to the next image...
# Image number 373 augmented. Mooving on to the next image...
# Image number 374 augmented. Mooving on to the next image...
# Image number 375 augmented. Mooving on to the next image...
# Image number 376 augmented. Mooving on to the next image...
# Image number 377 augmented. Mooving on to the next image...
# Image number 378 augmented. Mooving on to the next image...
# Image number 379 augmented. Mooving on to the next image...
# Image number 380 augmented. Mooving on to the next image...
# Image number 381 augmented. Mooving on to the next image...
# Image number 382 augmented. Mooving on to the next image...
# Image number 383 augmented. Mooving on to the next image...
# Image number 384 augmented. Mooving on to the next image...
# Image number 385 augmented. Mooving on to the next image...
# Image number 386 augmented. Mooving on to the next image...
# Image number 387 augmented. Mooving on to the next image...
# Image number 388 augmented. Mooving on to the next image...
# Image number 389 augmented. Mooving on to the next image...
# Image number 390 augmented. Mooving on to the next image...
# Image number 391 augmented. Mooving on to the next image...
# Image number 392 augmented. Mooving on to the next image...
# Image number 393 augmented. Mooving on to the next image...
# Image number 394 augmented. Mooving on to the next image...
# Image number 395 augmented. Mooving on to the next image...
# Image number 396 augmented. Mooving on to the next image...
# Image number 397 augmented. Mooving on to the next image...
# Image number 398 augmented. Mooving on to the next image...
# Image number 399 augmented. Mooving on to the next image...
# Image number 400 augmented. Mooving on to the next image...
# Image number 401 augmented. Mooving on to the next image...
# Image number 402 augmented. Mooving on to the next image...
# Image number 403 augmented. Mooving on to the next image...
# Image number 404 augmented. Mooving on to the next image...
# Image number 405 augmented. Mooving on to the next image...
# Image number 406 augmented. Mooving on to the next image...
# Image number 407 augmented. Mooving on to the next image...
# Image number 408 augmented. Mooving on to the next image...
# Image number 409 augmented. Mooving on to the next image...
# Image number 410 augmented. Mooving on to the next image...
# Image number 411 augmented. Mooving on to the next image...
# Image number 412 augmented. Mooving on to the next image...
# Image number 413 augmented. Mooving on to the next image...
# Image number 414 augmented. Mooving on to the next image...
# Image number 415 augmented. Mooving on to the next image...
# Image number 416 augmented. Mooving on to the next image...
# Image number 417 augmented. Mooving on to the next image...
# Image number 418 augmented. Mooving on to the next image...
# Image number 419 augmented. Mooving on to the next image...
# Image number 420 augmented. Mooving on to the next image...
# Image number 421 augmented. Mooving on to the next image...
# Image number 422 augmented. Mooving on to the next image...
# Image number 423 augmented. Mooving on to the next image...
# Image number 424 augmented. Mooving on to the next image...
# Image number 425 augmented. Mooving on to the next image...
# Image number 426 augmented. Mooving on to the next image...
# Image number 427 augmented. Mooving on to the next image...
# Image number 428 augmented. Mooving on to the next image...
# Image number 429 augmented. Mooving on to the next image...
# Image number 430 augmented. Mooving on to the next image...
# Image number 431 augmented. Mooving on to the next image...
# Image number 432 augmented. Mooving on to the next image...
# Image number 433 augmented. Mooving on to the next image...
# Image number 434 augmented. Mooving on to the next image...
# Image number 435 augmented. Mooving on to the next image...
# Image number 436 augmented. Mooving on to the next image...
# Image number 437 augmented. Mooving on to the next image...
# Image number 438 augmented. Mooving on to the next image...
# Image number 439 augmented. Mooving on to the next image...
# Image number 440 augmented. Mooving on to the next image...
# Image number 441 augmented. Mooving on to the next image...
# Image number 442 augmented. Mooving on to the next image...
# Image number 443 augmented. Mooving on to the next image...
# Image number 444 augmented. Mooving on to the next image...
# Image number 445 augmented. Mooving on to the next image...
# Image number 446 augmented. Mooving on to the next image...
# Image number 447 augmented. Mooving on to the next image...
# Image number 448 augmented. Mooving on to the next image...
# Image number 449 augmented. Mooving on to the next image...
# Image number 450 augmented. Mooving on to the next image...
# Image number 451 augmented. Mooving on to the next image...
# Image number 452 augmented. Mooving on to the next image...
# Image number 453 augmented. Mooving on to the next image...
# Image number 454 augmented. Mooving on to the next image...
# Image number 455 augmented. Mooving on to the next image...
# Image number 456 augmented. Mooving on to the next image...
# Image number 457 augmented. Mooving on to the next image...
# Image number 458 augmented. Mooving on to the next image...
# Image number 459 augmented. Mooving on to the next image...
# Image number 460 augmented. Mooving on to the next image...
# Image number 461 augmented. Mooving on to the next image...
# Image number 462 augmented. Mooving on to the next image...
# Image number 463 augmented. Mooving on to the next image...
# Image number 464 augmented. Mooving on to the next image...
# Image number 465 augmented. Mooving on to the next image...
# Image number 466 augmented. Mooving on to the next image...
# Image number 467 augmented. Mooving on to the next image...
# Image number 468 augmented. Mooving on to the next image...
# Image number 469 augmented. Mooving on to the next image...
# Image number 470 augmented. Mooving on to the next image...
# Image number 471 augmented. Mooving on to the next image...
# Image number 472 augmented. Mooving on to the next image...
# Image number 473 augmented. Mooving on to the next image...
# Image number 474 augmented. Mooving on to the next image...
# Image number 475 augmented. Mooving on to the next image...
# Image number 476 augmented. Mooving on to the next image...
# Image number 477 augmented. Mooving on to the next image...
# Image number 478 augmented. Mooving on to the next image...
# Image number 479 augmented. Mooving on to the next image...
# Image number 480 augmented. Mooving on to the next image...
# Image number 481 augmented. Mooving on to the next image...
# Image number 482 augmented. Mooving on to the next image...
# Image number 483 augmented. Mooving on to the next image...
# Image number 484 augmented. Mooving on to the next image...
# Image number 485 augmented. Mooving on to the next image...
# Image number 486 augmented. Mooving on to the next image...
# Image number 487 augmented. Mooving on to the next image...
# Image number 488 augmented. Mooving on to the next image...
# Image number 489 augmented. Mooving on to the next image...
# Image number 490 augmented. Mooving on to the next image...
# Image number 491 augmented. Mooving on to the next image...
# Image number 492 augmented. Mooving on to the next image...
# Image number 493 augmented. Mooving on to the next image...
# Image number 494 augmented. Mooving on to the next image...
# Image number 495 augmented. Mooving on to the next image...
# Image number 496 augmented. Mooving on to the next image...
# Image number 497 augmented. Mooving on to the next image...
# Image number 498 augmented. Mooving on to the next image...
# Image number 499 augmented. Mooving on to the next image...
# Image number 500 augmented. Mooving on to the next image...
# Image number 501 augmented. Mooving on to the next image...
# Image number 502 augmented. Mooving on to the next image...
# Image number 503 augmented. Mooving on to the next image...
# Image number 504 augmented. Mooving on to the next image...
# Image number 505 augmented. Mooving on to the next image...
# Image number 506 augmented. Mooving on to the next image...
# Image number 507 augmented. Mooving on to the next image...
# Image number 508 augmented. Mooving on to the next image...
# Image number 509 augmented. Mooving on to the next image...
# Image number 510 augmented. Mooving on to the next image...
# Image number 511 augmented. Mooving on to the next image...
# Image number 512 augmented. Mooving on to the next image...
# Image number 513 augmented. Mooving on to the next image...
# Image number 514 augmented. Mooving on to the next image...
# Image number 515 augmented. Mooving on to the next image...
# Image number 516 augmented. Mooving on to the next image...
# Image number 517 augmented. Mooving on to the next image...
# Image number 518 augmented. Mooving on to the next image...
# Image number 519 augmented. Mooving on to the next image...
# Image number 520 augmented. Mooving on to the next image...
# Image number 521 augmented. Mooving on to the next image...
# Image number 522 augmented. Mooving on to the next image...
# Image number 523 augmented. Mooving on to the next image...
# Image number 524 augmented. Mooving on to the next image...
# Image number 525 augmented. Mooving on to the next image...
# Image number 526 augmented. Mooving on to the next image...
# Image number 527 augmented. Mooving on to the next image...
# Image number 528 augmented. Mooving on to the next image...
# Image number 529 augmented. Mooving on to the next image...
# Image number 530 augmented. Mooving on to the next image...
# Image number 531 augmented. Mooving on to the next image...
# Image number 532 augmented. Mooving on to the next image...
# Image number 533 augmented. Mooving on to the next image...
# Image number 534 augmented. Mooving on to the next image...
# Image number 535 augmented. Mooving on to the next image...
# Image number 536 augmented. Mooving on to the next image...
# Image number 537 augmented. Mooving on to the next image...
# Image number 538 augmented. Mooving on to the next image...
# Image number 539 augmented. Mooving on to the next image...
# Image number 540 augmented. Mooving on to the next image...
# Image number 541 augmented. Mooving on to the next image...
# Image number 542 augmented. Mooving on to the next image...
# Image number 543 augmented. Mooving on to the next image...
# Image number 544 augmented. Mooving on to the next image...
# Image number 545 augmented. Mooving on to the next image...
# Image number 546 augmented. Mooving on to the next image...
# Image number 547 augmented. Mooving on to the next image...
# Image number 548 augmented. Mooving on to the next image...
# Image number 549 augmented. Mooving on to the next image...
# Image number 550 augmented. Mooving on to the next image...
# Image number 551 augmented. Mooving on to the next image...
# Image number 552 augmented. Mooving on to the next image...
# Image number 553 augmented. Mooving on to the next image...
# Image number 554 augmented. Mooving on to the next image...
# Image number 555 augmented. Mooving on to the next image...
# Image number 556 augmented. Mooving on to the next image...
# Image number 557 augmented. Mooving on to the next image...
# Image number 558 augmented. Mooving on to the next image...
# Image number 559 augmented. Mooving on to the next image...
# Image number 560 augmented. Mooving on to the next image...
# Image number 561 augmented. Mooving on to the next image...
# Image number 562 augmented. Mooving on to the next image...
# Image number 563 augmented. Mooving on to the next image...
# Image number 564 augmented. Mooving on to the next image...
# Image number 565 augmented. Mooving on to the next image...
# Image number 566 augmented. Mooving on to the next image...
# Image number 567 augmented. Mooving on to the next image...
# Image number 568 augmented. Mooving on to the next image...
# Image number 569 augmented. Mooving on to the next image...
# Image number 570 augmented. Mooving on to the next image...
# Image number 571 augmented. Mooving on to the next image...
# Image number 572 augmented. Mooving on to the next image...
# Image number 573 augmented. Mooving on to the next image...
# Image number 574 augmented. Mooving on to the next image...
# Image number 575 augmented. Mooving on to the next image...
# Image number 576 augmented. Mooving on to the next image...
# Image number 577 augmented. Mooving on to the next image...
# Image number 578 augmented. Mooving on to the next image...
# Image number 579 augmented. Mooving on to the next image...
# Image number 580 augmented. Mooving on to the next image...
# Image number 581 augmented. Mooving on to the next image...
# Image number 582 augmented. Mooving on to the next image...
# Image number 583 augmented. Mooving on to the next image...
# Image number 584 augmented. Mooving on to the next image...
# Image number 585 augmented. Mooving on to the next image...
# Image number 586 augmented. Mooving on to the next image...
# Image number 587 augmented. Mooving on to the next image...
# Image number 588 augmented. Mooving on to the next image...
# Image number 589 augmented. Mooving on to the next image...
# Image number 590 augmented. Mooving on to the next image...
# Image number 591 augmented. Mooving on to the next image...
# Image number 592 augmented. Mooving on to the next image...
# Image number 593 augmented. Mooving on to the next image...
# Image number 594 augmented. Mooving on to the next image...
# Image number 595 augmented. Mooving on to the next image...
# Image number 596 augmented. Mooving on to the next image...
# Image number 597 augmented. Mooving on to the next image...
# Image number 598 augmented. Mooving on to the next image...
# Image number 599 augmented. Mooving on to the next image...
# Image number 600 augmented. Mooving on to the next image...
# Image number 601 augmented. Mooving on to the next image...
# Image number 602 augmented. Mooving on to the next image...
# Image number 603 augmented. Mooving on to the next image...
# Image number 604 augmented. Mooving on to the next image...
# Image number 605 augmented. Mooving on to the next image...
# Image number 606 augmented. Mooving on to the next image...
# Image number 607 augmented. Mooving on to the next image...
# Image number 608 augmented. Mooving on to the next image...
# Image number 609 augmented. Mooving on to the next image...
# Image number 610 augmented. Mooving on to the next image...
# Image number 611 augmented. Mooving on to the next image...
# Image number 612 augmented. Mooving on to the next image...
# Image number 613 augmented. Mooving on to the next image...
# Image number 614 augmented. Mooving on to the next image...
# Image number 615 augmented. Mooving on to the next image...
# Image number 616 augmented. Mooving on to the next image...
# Image number 617 augmented. Mooving on to the next image...
# Image number 618 augmented. Mooving on to the next image...
# Image number 619 augmented. Mooving on to the next image...
# Image number 620 augmented. Mooving on to the next image...
# Image number 621 augmented. Mooving on to the next image...
# Image number 622 augmented. Mooving on to the next image...
# Image number 623 augmented. Mooving on to the next image...
# Image number 624 augmented. Mooving on to the next image...
# Image number 625 augmented. Mooving on to the next image...
# Image number 626 augmented. Mooving on to the next image...
# Image number 627 augmented. Mooving on to the next image...
# Image number 628 augmented. Mooving on to the next image...
# Image number 629 augmented. Mooving on to the next image...
# Image number 630 augmented. Mooving on to the next image...
# Image number 631 augmented. Mooving on to the next image...
# Image number 632 augmented. Mooving on to the next image...
# Image number 633 augmented. Mooving on to the next image...
# Image number 634 augmented. Mooving on to the next image...
# Image number 635 augmented. Mooving on to the next image...
# Image number 636 augmented. Mooving on to the next image...
# Image number 637 augmented. Mooving on to the next image...
# Image number 638 augmented. Mooving on to the next image...
# Image number 639 augmented. Mooving on to the next image...
# Image number 640 augmented. Mooving on to the next image...
# Image number 641 augmented. Mooving on to the next image...
# Image number 642 augmented. Mooving on to the next image...
# Image number 643 augmented. Mooving on to the next image...
# Image number 644 augmented. Mooving on to the next image...
# Image number 645 augmented. Mooving on to the next image...
# Image number 646 augmented. Mooving on to the next image...
# Image number 647 augmented. Mooving on to the next image...
# Image number 648 augmented. Mooving on to the next image...
# Image number 649 augmented. Mooving on to the next image...
# Image number 650 augmented. Mooving on to the next image...
# Image number 651 augmented. Mooving on to the next image...
# Image number 652 augmented. Mooving on to the next image...
# Image number 653 augmented. Mooving on to the next image...
# Image number 654 augmented. Mooving on to the next image...
# Image number 655 augmented. Mooving on to the next image...
# Image number 656 augmented. Mooving on to the next image...
# Image number 657 augmented. Mooving on to the next image...
# Image number 658 augmented. Mooving on to the next image...
# Image number 659 augmented. Mooving on to the next image...
# Image number 660 augmented. Mooving on to the next image...
# Image number 661 augmented. Mooving on to the next image...
# Image number 662 augmented. Mooving on to the next image...
# Image number 663 augmented. Mooving on to the next image...
# Image number 664 augmented. Mooving on to the next image...
# Image number 665 augmented. Mooving on to the next image...
# Image number 666 augmented. Mooving on to the next image...
# Image number 667 augmented. Mooving on to the next image...
# Image number 668 augmented. Mooving on to the next image...
# Image number 669 augmented. Mooving on to the next image...
# Image number 670 augmented. Mooving on to the next image...
# Image number 671 augmented. Mooving on to the next image...
# Image number 672 augmented. Mooving on to the next image...
# Image number 673 augmented. Mooving on to the next image...
# Image number 674 augmented. Mooving on to the next image...
# Image number 675 augmented. Mooving on to the next image...
# Image number 676 augmented. Mooving on to the next image...
# Image number 677 augmented. Mooving on to the next image...
# Image number 678 augmented. Mooving on to the next image...
# Image number 679 augmented. Mooving on to the next image...
# Image number 680 augmented. Mooving on to the next image...
# Image number 681 augmented. Mooving on to the next image...
# Image number 682 augmented. Mooving on to the next image...
# Image number 683 augmented. Mooving on to the next image...
# Image number 684 augmented. Mooving on to the next image...
# Image number 685 augmented. Mooving on to the next image...
# Image number 686 augmented. Mooving on to the next image...
# Image number 687 augmented. Mooving on to the next image...
# Image number 688 augmented. Mooving on to the next image...
# Image number 689 augmented. Mooving on to the next image...
# Image number 690 augmented. Mooving on to the next image...
# Image number 691 augmented. Mooving on to the next image...
# Image number 692 augmented. Mooving on to the next image...
# Image number 693 augmented. Mooving on to the next image...
# Image number 694 augmented. Mooving on to the next image...
# Image number 695 augmented. Mooving on to the next image...
# Image number 696 augmented. Mooving on to the next image...
# Image number 697 augmented. Mooving on to the next image...
# Image number 698 augmented. Mooving on to the next image...
# Image number 699 augmented. Mooving on to the next image...
# Image number 700 augmented. Mooving on to the next image...
# Image number 701 augmented. Mooving on to the next image...
# Image number 702 augmented. Mooving on to the next image...
# Image number 703 augmented. Mooving on to the next image...
# Image number 704 augmented. Mooving on to the next image...
# Image number 705 augmented. Mooving on to the next image...
# Image number 706 augmented. Mooving on to the next image...
# Image number 707 augmented. Mooving on to the next image...
# Image number 708 augmented. Mooving on to the next image...
# Image number 709 augmented. Mooving on to the next image...
# Image number 710 augmented. Mooving on to the next image...
# Image number 711 augmented. Mooving on to the next image...
# Image number 712 augmented. Mooving on to the next image...
# Image number 713 augmented. Mooving on to the next image...
# Image number 714 augmented. Mooving on to the next image...
# Image number 715 augmented. Mooving on to the next image...
# Image number 716 augmented. Mooving on to the next image...
# Image number 717 augmented. Mooving on to the next image...
# Image number 718 augmented. Mooving on to the next image...

# %%
from google.colab import files
import shutil

folder_path = DIR
destination_path = '//Users/darshabi/Desktop/TEST.zip'
shutil.make_archive('/content/augmented_folder', 'zip', folder_path)
files.download('/content/augmented_folder.zip')

# %% [markdown]
# # For testing - deleting all Augmented pics in the directory

# %%
for filename in os.listdir(DIR):
    if "_augmented" in filename:  # check if "_augmented" is in the filename
        os.remove(os.path.join(DIR, filename))
        print(f"Deleted: {filename}")
# Out:
# Deleted: 5_vid6_340_augmented_0_9811.jpeg
# Deleted: 1_vid26_1180_augmented_0_6597.jpeg
# Deleted: 1_vid26_2340_augmented_0_8677.jpeg
# Deleted: 1_vid25_60_augmented_0_3481.jpeg
# Deleted: 0_vid15 (check for blur etc)_400_augmented_0